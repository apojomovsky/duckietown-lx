# %% [markdown]
# <p style="text-align: right">
#   <img src="../../assets/images/dtlogo.png" alt="Logo" width="200">
# </p>

# %% [markdown]
# # 💻 🚙 06 - PID: Heading control (SOLUTION)

# %%
import numpy as np

# Heading control
# Do not change the name of the function, inputs or outputs. It will break things.

def PIDController(v_0, theta_ref, theta_hat, prev_e, prev_int, delta_t): #add theta_ref as input
    """
    Args:
        v_0 (:double:) linear Duckiebot speed (given).
        theta_ref (:double:) reference heading pose
        theta_hat (:double:) the current estiamted theta.
        prev_e (:double:) tracking error at previous iteration.
        prev_int (:double:) previous integral error term.
        delta_t (:double:) time interval since last call.
    returns:
        v_0 (:double:) linear velocity of the Duckiebot 
        omega (:double:) angular velocity of the Duckiebot
        e (:double:) current tracking error (automatically becomes prev_e_y at next iteration).
        e_int (:double:) current integral error (automatically becomes prev_int_y at next iteration).
    """
    
   # Tracking error
    e = theta_ref - theta_hat

    # integral of the error
    e_int = prev_int + e*delta_t

    # anti-windup - preventing the integral error from growing too much
    e_int = max(min(e_int,2),-2)

    # derivative of the error
    e_der = (e - prev_e)/delta_t

    # controller coefficients
    Kp = 5
    Ki = 0.2
    Kd = 0.1

    # PID controller for omega
    omega = Kp*e + Ki*e_int + Kd*e_der
    
    #print(f"\n\nDelta time : {delta_t} \nE : {np.rad2deg(e)} \nE int : {e_int} \nPrev e : {prev_e} \nU : {u} \nTheta hat: {np.rad2deg(theta_hat)} \n")
     
    return v_0, omega, e, e_int

# %%
import matplotlib.pyplot as plt
import numpy as np 

import sys
sys.path.append('../../')
from tests.unit_test import UnitTestHeadingPID

# This is for quick testing purposes only - you can try different values of v_init and R, L or the ones you determined before. Try to change R, L for fun.
v_test = 0.2
R_test = 0.033 # m
baseline_test = 0.09 # m
gain_test = 0.6 
trim_test = 0 
thata_ref= 50*np.pi/180 # in rad

# Sanity check (not a faithful representation of the actual behavior, given the motion model is assumed to be exactly known)
unit_test = UnitTestHeadingPID(R_test, baseline_test, v_test,thata_ref, gain_test, trim_test, PIDController) 
unit_test.test()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      16 # Sanity check (not a faithful representation of the actual behavior, given the motion model is assumed to be exactly known)
#      17 unit_test = UnitTestHeadingPID(R_test, baseline_test, v_test,thata_ref, gain_test, trim_test, PIDController)
# ---> 18 unit_test.test()
#
# File /code/modcon/packages/tests/unit_test.py:162, in UnitTestHeadingPID.test(self)
#     159     self.v_0 = v_0
#     161 # plot theta with noise and the error on theta
# --> 162 self.plot_pose(theta_hat_, err_, "Theta with noise", "Time (s)", "Theta (Degree)")
#     163 # plot the input to the wheels
#     164 self.plot_input(u_r_, u_l_, "Control inputs", "Time (s)", "PWM")
#
# File /code/modcon/packages/tests/unit_test.py:188, in UnitTestHeadingPID.plot_pose(self, theta_hat_, err_, title, x_label, y_label)
#     186 plt.xlabel(x_label)
#     187 plt.ylabel(y_label)
# --> 188 plt.xticks(np.arange(0, len(theta_hat_) + 1, 1))
#     190 theta_hat_deg = []
#     191 for el in theta_hat_:
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:1533, in xticks(ticks, labels, **kwargs)
#    1531     labels = ax.get_xticklabels()
#    1532 elif labels is None:
# -> 1533     locs = ax.set_xticks(ticks)
#    1534     labels = ax.get_xticklabels()
#    1535 else:
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:3350, in _AxesBase.set_xticks(self, ticks, minor)
#    3337 def set_xticks(self, ticks, minor=False):
#    3338     """
#    3339     Set the x ticks with list of *ticks*
#    3340
#    (...)
#    3348         Default is ``False``.
#    3349     """
# -> 3350     ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3351     self.stale = True
#    3352     return ret
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1763, in Axis.set_ticks(self, ticks, minor)
#    1761 else:
#    1762     self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1763     return self.get_major_ticks(len(ticks))
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1411, in Axis.get_major_ticks(self, numticks)
#    1407     numticks = len(self.get_majorticklocs())
#    1409 while len(self.majorTicks) < numticks:
#    1410     # Update the new tick label properties from the old.
# -> 1411     tick = self._get_tick(major=True)
#    1412     self.majorTicks.append(tick)
#    1413     tick.gridline.set_visible(self._gridOnMajor)
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:1933, in XAxis._get_tick(self, major)
#    1931 else:
#    1932     tick_kw = self._minor_tick_kw
# -> 1933 return XTick(self.axes, 0, '', major=major, **tick_kw)
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:158, in Tick.__init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     154 self._grid_kw = {k[5:]: v for k, v in kw.items()}
#     156 self.apply_tickdir(tickdir)
# --> 158 self.tick1line = self._get_tick1line()
#     159 self.tick2line = self._get_tick2line()
#     160 self.gridline = self._get_gridline()
#
# File /usr/lib/python3/dist-packages/matplotlib/axis.py:461, in XTick._get_tick1line(self)
#     459 'Get the default line2D instance'
#     460 # x in data coords, y in axes coords
# --> 461 l = mlines.Line2D(xdata=(0,), ydata=(0,), color=self._color,
#     462                   linestyle='None', marker=self._tickmarkers[0],
#     463                   markersize=self._size,
#     464                   markeredgewidth=self._width, zorder=self._zorder)
#     465 l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     466 self._set_artist_props(l)
#
# File /usr/lib/python3/dist-packages/matplotlib/lines.py:382, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380 self._color = None
#     381 self.set_color(color)
# --> 382 self._marker = MarkerStyle(marker, fillstyle)
#     384 self._markevery = None
#     385 self._markersize = None
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:242, in MarkerStyle.__init__(self, marker, fillstyle)
#     224 """
#     225 Attributes
#     226 ----------
#    (...)
#     239     'full', 'left", 'right', 'bottom', 'top', 'none'
#     240 """
#     241 self._marker_function = None
# --> 242 self.set_fillstyle(fillstyle)
#     243 self.set_marker(marker)
#
# File /usr/lib/python3/dist-packages/matplotlib/markers.py:277, in MarkerStyle.set_fillstyle(self, fillstyle)
#     275 if fillstyle is None:
#     276     fillstyle = rcParams['markers.fillstyle']
# --> 277 if fillstyle not in self.fillstyles:
#     278     raise ValueError("Unrecognized fillstyle %s"
#     279                      % ' '.join(self.fillstyles))
#     280 self._fillstyle = fillstyle
#
# KeyboardInterrupt:
